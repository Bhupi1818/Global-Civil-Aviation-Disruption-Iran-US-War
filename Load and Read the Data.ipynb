# %%
import pandas as pd
import matplotlib.pyplot as plt

#load the data
df = pd.read_csv('/Users/bhupendrasaini/Downloads/airline_losses.csv')
print('The info')
print(df.info())
print('First 5 rows')
print(df.head())
print('First 5 columns')
print(df.tail())
print('Number of rows,Number of columns')
print(df.shape)
print('Auto descriptive Statics')
print(df.describe())
# Out:
# The info
# <class 'pandas.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   airline              33 non-null     str
#  1   country              33 non-null     str
#  2   airline_type         33 non-null     str
#  3   estimated_loss_usd   33 non-null     float64
#  4   cancellations_count  33 non-null     int64
#  5   reroutes_count       33 non-null     int64
#  6   revenue_loss_pct     33 non-null     float64
#  7   region               33 non-null     str
# dtypes: float64(2), int64(2), str(4)
# memory usage: 2.2 KB
# None
# First 5 rows
#            airline country  airline_type  estimated_loss_usd  \
# 0    Qatar Airways   Qatar  Flag Carrier         889080000.0
# 1   Etihad Airways     UAE  Flag Carrier         863980000.0
# 2   Kuwait Airways  Kuwait  Flag Carrier         824320000.0
# ...
